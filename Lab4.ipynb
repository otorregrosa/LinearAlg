# %% [markdown]
# <a href="https://colab.research.google.com/github/otorregrosa/LinearAlg/blob/main/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# Task 1

# %%
A = np.array([1,2,3,4])
B = np.array([1,3,5,7])
C = np.array([2,4,6,8])
D = np.array([5,6,7,8])
E = np.array([9,11,13,15])
F = np.array([10,12,14,16])

# %%
Z = (A**(2))
A1 = (sum(Z))
A2 = (A1**(1/2))
print(A2)
# Out:
# 5.477225575051661

# %% [markdown]
# Task 2

# %%
G = np.array([1,2,3,4,5])
H = np.array([5,10,15,20,25])
I = np.array([2,4,6,8,10])
J = np.array([1,3,5,7,9])
K = np.array([3,6,9,12,15])

# %%
dotproduct=0
for H,G in zip(H,G):
    dotproduct = dotproduct+H*G
print('Dot product is:', dotproduct)
# Out:
# Dot product is: 275

# %% [markdown]
# Task 3

# %%
a = np.array([-0.4,4.3,-0.6])
b = np.array([-0.2,0.2,1])
c = np.array([-0.2,2.1,-1.5])
d = sum(a,b)
z = abs(d)
d1 = sum(d,c)
a2 = np.square(a)
b2 = np.square(b)
c2 = np.square(c)
d2 = sum(a2,b2)
d3 = sum(d2,c2)
e = sum(b, a*b)
f = a*e
g = np.array(f/c)
h = np.multiply(d3, g*d)
print(h)
# Out:
# [389.3724  833.3916   41.52768]

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax.plot(X,Y,Z)
ax.plot(h,h ,'y')
#ax.plot(a,a , 'b')
#ax.plot(b,b,  'k')
ax.plot(c,c,  'red')

plt.show()
